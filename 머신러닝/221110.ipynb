# %% [markdown]
# ## 성능 평가
# - 대표적인 회귀 모델 평가 지표
#   1. MSE(Mean Squared Error)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - 평가 지표에서는 평균을 사용해야 한다.
#   - [0, +∞]
#   - target value 단위에 영향을 받는다.

# %% [markdown]
#   2. R^2 Score(Coefficient of Determination)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - SSR / SST를 이용하여 얼마나 개선되었는지 확인
# - Best case = 1, Worst case = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 음수가 나오는 경우 : nonlinear regression의 경우 음수가 나올 수도 있음.
