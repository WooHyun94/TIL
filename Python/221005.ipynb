# %%
import pandas as pd    
import numpy as np   
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
x = [1, 2, 3]
y = [4, 5, 6]

# %%
plt.figure(figsize = (8, 6))
plt.plot(x, y)
plt.show()
